# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravinderram/ASDA_2025_Group_2_Portfolio/blob/main/week_02_group_2_notebook_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic EDA of two datasets
# Dataset 1: California Housing Prices

import kagglehub
import pandas as pd

# 1. Dataset overview
# Download latest version
path = kagglehub.dataset_download("camnugent/california-housing-prices")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'california-housing-prices' dataset.
# Path to dataset files: /kaggle/input/california-housing-prices

# %%
# Name dataset
housing_df = pd.read_csv(f"{path}/housing.csv")

# %%
# Get rows and columns of dataset
housing_df.shape
# Out:
# (20640, 10)

# %%
# Get column names
housing_df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Get column types
housing_df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# Get non-null counts
housing_df.notnull().sum()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
# Get number of unique values in each column
housing_df.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# median_house_value     3842
# ocean_proximity           5
# dtype: int64

# %%
# Get random sample of 5 rows to see example values
examples = housing_df.sample(5)
examples
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14114    -117.11     32.74                33.0       1126.0           267.0
# 16161    -122.49     37.78                49.0       2176.0           441.0
# 9842     -121.90     36.60                33.0       2461.0           649.0
# 10498    -117.67     33.51                18.0       1645.0           393.0
# 1883     -119.99     38.94                22.0       3119.0           640.0
#
#        population  households  median_income  median_house_value  \
# 14114       621.0       241.0         3.2422            123100.0
# 16161      1040.0       448.0         4.2414            500001.0
# 9842       1234.0       601.0         2.8727            225000.0
# 10498      1490.0       355.0         3.4792            126400.0
# 1883        786.0       351.0         3.0806            118500.0
#
#       ocean_proximity
# 14114      NEAR OCEAN
# 16161        NEAR BAY
# 9842       NEAR OCEAN
# 10498       <1H OCEAN
# 1883           INLAND

# %%
# Create summary table
summary_2 = pd.DataFrame({"Column name":housing_df.columns, "Data type": housing_df.dtypes, "Non-null count": housing_df.notnull().sum(), "Unique values":housing_df.nunique()})

summary_2["Examples"] = [
    ", ".join(map(str, examples[col].tolist()))
    for col in housing_df.columns
]

summary_2 = summary_2.reset_index(drop=True)

markdown_table = summary_2.to_markdown(index=False)
print(markdown_table)
# Out:
# | Column name        | Data type   |   Non-null count |   Unique values | Examples                                            |
# |:-------------------|:------------|-----------------:|----------------:|:----------------------------------------------------|
# | longitude          | float64     |            20640 |             844 | -117.11, -122.49, -121.9, -117.67, -119.99          |
# | latitude           | float64     |            20640 |             862 | 32.74, 37.78, 36.6, 33.51, 38.94                    |
# | housing_median_age | float64     |            20640 |              52 | 33.0, 49.0, 33.0, 18.0, 22.0                        |
# | total_rooms        | float64     |            20640 |            5926 | 1126.0, 2176.0, 2461.0, 1645.0, 3119.0              |
# | total_bedrooms     | float64     |            20433 |            1923 | 267.0, 441.0, 649.0, 393.0, 640.0                   |
# | population         | float64     |            20640 |            3888 | 621.0, 1040.0, 1234.0, 1490.0, 786.0                |
# | households         | float64     |            20640 |            1815 | 241.0, 448.0, 601.0, 355.0, 351.0                   |
# | median_income      | float64     |            20640 |           12928 | 3.2422, 4.2414, 2.8727, 3.4792, 3.0806              |
# | median_house_value | float64     |            20640 |            3842 | 123100.0, 500001.0, 225000.0, 126400.0, 118500.0    |
# | ocean_proximity    | object      |            20640 |               5 | NEAR OCEAN, NEAR BAY, NEAR OCEAN, <1H OCEAN, INLAND |

# %%
# Descriptive Statistics for Numeric Columns

housing_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
# Descriptive Statistics for Categorical / Object Columns
housing_df.describe(include="object")
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %%
#checking duplicates in the dataframe
housing_df.duplicated().sum()
print(f"this dataset has {int(housing_df.duplicated().sum())} duplicates")
# Out:
# this dataset has 0 duplicates

# %%
# Missing Values
missing_percent = (housing_df.isna().sum() / len(housing_df)) * 100
print(housing_df.isna().sum(),missing_percent.round(2))
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64 longitude             0.0
# latitude              0.0
# housing_median_age    0.0
# total_rooms           0.0
# total_bedrooms        1.0
# population            0.0
# households            0.0
# median_income         0.0
# median_house_value    0.0
# ocean_proximity       0.0
# dtype: float64
